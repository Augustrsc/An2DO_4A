# %%
##Clustering Spectrale
import matplotlib.pyplot as plt
import numpy as np



import pyreadr

result = pyreadr.read_r("../data/processed/data_features_core.rds")
df = result[None]  # None = clé par défaut pour un objet RDS unique

#data = df.to_numpy()
df_quanti = df.select_dtypes(include='number')
data = df_quanti.to_numpy()

from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
data_scaled = ss.fit_transform(data)

# %%
##clustering spectrale
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from graspologic.inference import SBMEstimation
#       2 from sklearn.metrics.pairwise import cosine_similarity
#       4 # 1. Préparer votre matrice d'adjacence (comme avant)
#
# ImportError: cannot import name 'SBMEstimation' from 'graspologic.inference' (/home/deleri/Documents/4A/Analyse_Données/Projet_Correct/An2DO_4A/.venv/lib/python3.11/site-packages/graspologic/inference/__init__.py)
